# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
df.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21592  False  False  False     False      False        False     False
# 21593  False  False  False     False      False        False     False
# 21594  False  False  False     False      False        False     False
# 21595  False  False  False     False      False        False     False
# 21596  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.isnull().sum()
#False=0
#True=1
#Summing these up per columns
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms']) #Number of houses with 'x' number of bedrooms

# %%
df.corr()['price'].sort_values() # Finding correlation with price
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='price',y='sqft_living',data=df)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df)

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='long',y='lat',data=df,hue='price')

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
non_top_1_perc=df.sort_values('price',ascending=False).iloc[216:]

# %%
non_top_1_perc
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=non_top_1_perc,hue='price',edgecolor=None,alpha=0.3,palette='RdYlGn')

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df=df.drop('id',axis=1)

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date']=pd.to_datetime(df['date'])#Convert date into a date-time object

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year']=df['date'].apply(lambda date:date.year)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  year
# ...

# %%
df['month']=df['date'].apply(lambda date:date.month)

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# ...

# %%
df['day']=df['date'].apply(lambda x:x.month) #lambda function

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  yr_built  yr_renovated  \
# ...

# %%
df=df.drop('day',axis=1)

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='month',y='price',data=df)

# %%
df.groupby('month').mean()['price'] # have to use a math function with groupby funce like mean,max,min
# Out:
# month
# 1     525963.251534
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
df.groupby('month').mean()['price'].plot()

# %%
df.groupby('year').mean()['price'] # have to use a math function with groupby funce like mean,max,min
# Out:
# year
# 2014    539350.911777
# 2015    542279.005878
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,6))
df.groupby('year').mean()['price'].plot()

# %%
df=df.drop('date',axis=1)

# %%
df.head(10)
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   221900.0         3       1.00         1180      5650     1.0           0
# 1   538000.0         3       2.25         2570      7242     2.0           0
# 2   180000.0         2       1.00          770     10000     1.0           0
# 3   604000.0         4       3.00         1960      5000     1.0           0
# 4   510000.0         3       2.00         1680      8080     1.0           0
# 5  1230000.0         4       4.50         5420    101930     1.0           0
# 6   257500.0         3       2.25         1715      6819     2.0           0
# 7   291850.0         3       1.50         1060      9711     1.0           0
# 8   229500.0         3       1.00         1780      7470     1.0           0
# 9   323000.0         3       2.50         1890      6560     2.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
df['zipcode'].nunique()
# Out:
# 70

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df=df.drop('zipcode',axis=1)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts() # No basement = less value
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %% [markdown]
# # Creating Model

# %%
X = df.drop('price',axis=1).values

# %%
X
# Out:
# array([[3.000e+00, 1.000e+00, 1.180e+03, ..., 5.650e+03, 2.014e+03,
#         1.000e+01],
#        [3.000e+00, 2.250e+00, 2.570e+03, ..., 7.639e+03, 2.014e+03,
#         1.200e+01],
#        [2.000e+00, 1.000e+00, 7.700e+02, ..., 8.062e+03, 2.015e+03,
#         2.000e+00],
#        ...,
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 2.007e+03, 2.014e+03,
#         6.000e+00],
#        [3.000e+00, 2.500e+00, 1.600e+03, ..., 1.287e+03, 2.015e+03,
#         1.000e+00],
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 1.357e+03, 2.014e+03,
#         1.000e+01]])

# %%
y=df['price'].values

# %%
y
# Out:
# array([221900., 538000., 180000., ..., 402101., 400000., 325000.])

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))#last layer

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,batch_size=128, validation_data=(X_test,y_test),
          epochs=400)#batch size should be in powers of 2
# Out:
# Train on 15117 samples, validate on 6480 samples
# Epoch 1/400
# 15117/15117 [==============================] - 3s 181us/sample - loss: 430226067511.0035 - val_loss: 418834242714.2321
# Epoch 2/400
# 15117/15117 [==============================] - 0s 32us/sample - loss: 427821643234.7709 - val_loss: 410173278910.8938
# Epoch 3/400
# 15117/15117 [==============================] - 1s 36us/sample - loss: 391843990349.7805 - val_loss: 328379882326.5975
# Epoch 4/400
# 15117/15117 [==============================] - 0s 32us/sample - loss: 241850064877.5752 - val_loss: 137389751106.3704
# Epoch 5/400
# 15117/15117 [==============================] - 0s 28us/sample - loss: 109634747406.2928 - val_loss: 95730962047.6839
# Epoch 6/400
# 15117/15117 [==============================] - 0s 27us/sample - loss: 97894479454.8675 - val_loss: 93914759410.7259
# Epoch 7/400
# 15117/15117 [==============================] - 0s 27us/sample - loss: 95880717989.8573 - val_loss: 91970808551.3481
# Epoch 8/400
# ...

# %%
loss=pd.DataFrame(model.history.history)

# %%
loss.plot()

# %%
#model.history.history

# %%
pd.DataFrame(model.history.history)
# Out:
#              loss      val_loss
# 0    4.302261e+11  4.188342e+11
# 1    4.278216e+11  4.101733e+11
# 2    3.918440e+11  3.283799e+11
# 3    2.418501e+11  1.373898e+11
# 4    1.096347e+11  9.573096e+10
# ..            ...           ...
# 395  2.868298e+10  2.637171e+10
# 396  2.878388e+10  2.631773e+10
# 397  2.866847e+10  2.620504e+10
# 398  2.867175e+10  2.619038e+10
# 399  2.867104e+10  2.618466e+10
#
# [400 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score,accuracy_score

# %%
predictions=model.predict(X_test)

# %%
mean_squared_error(y_test,predictions)
# Out:
# 26184662554.04702

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 161816.75609789926

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 100292.71626398533

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8026241145107524

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r') #Perfect prediction line

# %%
single_house=df.drop('price',axis=1).iloc[0]

# %%
single_house.values
# Out:
# array([ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#         0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#         5.65000e+03,  2.01400e+03,  1.00000e+01])

# %%
single_house.values.reshape(-1,19)# -1= keep old dimensions along that axis
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#          5.65000e+03,  2.01400e+03,  1.00000e+01]])

# %%
single_house=scaler.transform(single_house.values.reshape(-1,19))

# %%
single_house
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.        , 0.81818182]])

# %%
model.predict(single_house)
# Out:
# array([[283380.3]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3        1.0         1180      5650     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
#
#        lat     long  sqft_living15  sqft_lot15  year  month
# 0  47.5112 -122.257           1340        5650  2014     10

# %%
non_top_1_perc
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
non_top_1_perc = non_top_1_perc.drop('id',axis=1)
non_top_1_perc = non_top_1_perc.drop('zipcode',axis=1)

# %%
scaler1=MinMaxScaler()

# %%
non_top_1_perc['date']=non_top_1_perc['date'].apply(pd.to_datetime)

# %%
non_top_1_perc['year']=non_top_1_perc['date'].apply(lambda x:x.year)
non_top_1_perc['month']=non_top_1_perc['date'].apply(lambda x:x.month)
non_top_1_perc=non_top_1_perc.drop('date',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-e04859ce528a> in <module>
# ...

# %%
non_top_1_perc
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6329   1970000.0         4       3.50         4370      8510     2.0
# 12271  1960000.0         5       4.50         6200     23373     3.0
# 9166   1960000.0         3       1.75         3330     12566     1.0
# 12565  1960000.0         4       4.00         4430     31353     2.0
# 1150   1960000.0         4       2.75         3120      7898     1.0
# ...          ...       ...        ...          ...       ...     ...
# 2139     82500.0         2       1.00          520     22334     1.0
# 8267     82000.0         3       1.00          860     10426     1.0
# 16184    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15279    78000.0         2       1.00          780     16344     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(non_top_1_perc.drop('price',axis=1).values, non_top_1_perc['price'].values, test_size=0.33, random_state=42)

# %%
scaler1.fit(X_train1)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train1=scaler1.transform(X_train1)
X_test1=scaler1.transform(X_test1)

# %%
X_train1.shape
# Out:
# (14325, 19)

# %%
X_train1
# Out:
# array([[0.03125   , 0.07142857, 0.09115646, ..., 0.01028787, 1.        ,
#         0.        ],
#        [0.0625    , 0.21428571, 0.09251701, ..., 0.00738967, 1.        ,
#         0.18181818],
#        [0.0625    , 0.21428571, 0.12244898, ..., 0.01038206, 1.        ,
#         0.18181818],
#        ...,
#        [0.09375   , 0.28571429, 0.28435374, ..., 0.03749971, 0.        ,
#         0.36363636],
#        [0.09375   , 0.42857143, 0.5292517 , ..., 0.01433248, 0.        ,
#         0.90909091],
#        [0.09375   , 0.21428571, 0.19047619, ..., 0.00946539, 0.        ,
#         0.72727273]])

# %%
model1 = Sequential()


model1.add(Dense(19,activation='relu'))
model1.add(Dense(19,activation='relu'))
model1.add(Dense(19,activation='relu'))
model1.add(Dense(19,activation='relu'))
model1.add(Dense(19,activation='relu'))
model1.add(Dense(19,activation='relu'))
model1.add(Dense(19,activation='relu'))

model1.add(Dense(1))

#Compile
model1.compile(optimizer='adam',loss='mse')

# %%
model1.fit(x=X_train1,y=y_train1,batch_size=32,epochs=400,validation_split=0.2,use_multiprocessing=True)
# Out:
# Train on 11460 samples, validate on 2865 samples
# Epoch 1/400
# 11460/11460 [==============================] - 1s 120us/sample - loss: 221667840288.7930 - val_loss: 51923160823.5113
# Epoch 2/400
# 11460/11460 [==============================] - 1s 68us/sample - loss: 49611801037.0681 - val_loss: 43798252610.8370
# Epoch 3/400
# 11460/11460 [==============================] - 1s 66us/sample - loss: 41437206039.0534 - val_loss: 36250750918.0984
# Epoch 4/400
# 11460/11460 [==============================] - 1s 67us/sample - loss: 34037680450.3902 - val_loss: 30188218708.9759- loss: 34829966020.3
# Epoch 5/400
# 11460/11460 [==============================] - 1s 67us/sample - loss: 29495179858.0272 - val_loss: 27423310353.6921
# Epoch 6/400
# 11460/11460 [==============================] - 1s 65us/sample - loss: 27172150995.7696 - val_loss: 25785684191.0283
# Epoch 7/400
# 11460/11460 [==============================] - 1s 73us/sample - loss: 25851803179.0688 - val_loss: 24885375610.7728
# ...

# %%
model1.history.history
# Out:
# {'loss': [221667840288.79303,
#   49611801037.06806,
#   41437206039.053406,
#   34037680450.39023,
#   29495179858.027225,
#   27172150995.769634,
#   25851803179.06876,
#   24968924354.79232,
#   24371961032.510994,
#   23992433794.635952,
#   23668951877.428272,
#   23382229947.375916,
#   23140291146.164047,
#   23043928458.58848,
#   22906122224.273647,
#   22759404778.823036,
#   22615091859.791973,
#   22383559173.539967,
#   22396363021.492496,
#   22241447788.208027,
#   22173825778.150085,
#   22115541536.34625,
#   21934328263.5281,
#   21917899529.739616,
#   21848893883.19721,
#   21743832027.18604,
#   21737366010.81745,
#   21624770199.72356,
#   21603782674.58569,
#   21588553082.50471,
#   21497171988.73019,
#   21484810803.289352,
#   21407025225.98534,
#   21378007207.271206,
#   21459396262.377663,
#   21355337457.077835,
#   21360398691.808727,
#   21281132544.0,
#   21331456647.63979,
#   21206524502.31623,
#   21182804198.53403,
#   21184582604.17452,
# ...

# %%
pd.DataFrame(model1.history.history)
# Out:
#              loss      val_loss
# 0    2.216678e+11  5.192316e+10
# 1    4.961180e+10  4.379825e+10
# 2    4.143721e+10  3.625075e+10
# 3    3.403768e+10  3.018822e+10
# 4    2.949518e+10  2.742331e+10
# ..            ...           ...
# 395  1.126542e+10  1.234791e+10
# 396  1.121927e+10  1.201524e+10
# 397  1.120338e+10  1.192528e+10
# 398  1.109180e+10  1.255492e+10
# 399  1.107266e+10  1.193301e+10
#
# [400 rows x 2 columns]

# %%
loss1=pd.DataFrame(model1.history.history)

# %%
plt.figure(figsize=(10,6))
loss1.plot()

# %%
predictions1=model1.predict(X_test1)

# %%
mean_squared_error(y_test1,predictions1)
# Out:
# 11075855349.21868

# %%
mean_absolute_error(y_test1,predictions1)
# Out:
# 68657.06611837444

# %%
explained_variance_score(y_test1,predictions1)
# Out:
# 0.861420641958746

# %%
guess=non_top_1_perc.drop('price',axis=1).iloc[0]

# %%
guess
# Out:
# bedrooms             4.0000
# bathrooms            3.5000
# sqft_living       4370.0000
# sqft_lot          8510.0000
# floors               2.0000
# waterfront           0.0000
# view                 1.0000
# condition            3.0000
# grade               10.0000
# sqft_above        3610.0000
# sqft_basement      760.0000
# yr_built          2003.0000
# yr_renovated         0.0000
# lat                 47.5876
# long              -122.2040
# sqft_living15     2960.0000
# sqft_lot15       10347.0000
# year              2014.0000
# month                6.0000
# Name: 6329, dtype: float64

# %%
guess
# Out:
# bedrooms             4.0000
# bathrooms            3.5000
# sqft_living       4370.0000
# sqft_lot          8510.0000
# floors               2.0000
# waterfront           0.0000
# view                 1.0000
# condition            3.0000
# grade               10.0000
# sqft_above        3610.0000
# sqft_basement      760.0000
# yr_built          2003.0000
# yr_renovated         0.0000
# lat                 47.5876
# long              -122.2040
# sqft_living15     2960.0000
# sqft_lot15       10347.0000
# year              2014.0000
# month                6.0000
# Name: 6329, dtype: float64

# %%
guess=guess.values.reshape(-1,19)

# %%
guess=scaler1.transform(guess)

# %%
print(model1.predict(guess))
print(model.predict(guess))
print(non_top_1_perc.iloc[0]['price'])
# Out:
# [[1368619.5]]
# [[1694189.8]]
# 1970000.0
